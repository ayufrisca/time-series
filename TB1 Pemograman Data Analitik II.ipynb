# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import pandas as pd
data=pd.read_csv("earthquakes.csv",sep=",")
print(data)
# Out:
#           date  Year  earthquakes_per_year
# 0   1900-01-01  1900                  13.0
# 1   1901-01-01  1901                  14.0
# 2   1902-01-01  1902                   8.0
# 3   1903-01-01  1903                  10.0
# 4   1904-01-01  1904                  16.0
# ..         ...   ...                   ...
# 94  1994-01-01  1994                  15.0
# 95  1995-01-01  1995                  25.0
# 96  1996-01-01  1996                  22.0
# 97  1997-01-01  1997                  20.0
# 98  1998-01-01  1998                  16.0
#
# [99 rows x 3 columns]

# %%
data.columns
# Out:
# Index(['date', 'Year', 'earthquakes_per_year'], dtype='object')

# %%
data["Year"]=pd.to_datetime(data["Year"])
data
# Out:
#           date                          Year  earthquakes_per_year
# 0   1900-01-01 1970-01-01 00:00:00.000001900                  13.0
# 1   1901-01-01 1970-01-01 00:00:00.000001901                  14.0
# 2   1902-01-01 1970-01-01 00:00:00.000001902                   8.0
# 3   1903-01-01 1970-01-01 00:00:00.000001903                  10.0
# 4   1904-01-01 1970-01-01 00:00:00.000001904                  16.0
# ..         ...                           ...                   ...
# 94  1994-01-01 1970-01-01 00:00:00.000001994                  15.0
# 95  1995-01-01 1970-01-01 00:00:00.000001995                  25.0
# 96  1996-01-01 1970-01-01 00:00:00.000001996                  22.0
# 97  1997-01-01 1970-01-01 00:00:00.000001997                  20.0
# 98  1998-01-01 1970-01-01 00:00:00.000001998                  16.0
#
# [99 rows x 3 columns]

# %%
data.dtypes
# Out:
# date                            object
# Year                    datetime64[ns]
# earthquakes_per_year           float64
# dtype: object

# %%
data=data.info()
print(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  99 non-null     object
#  1   Year                  99 non-null     datetime64[ns]
#  2   earthquakes_per_year  99 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 2.4+ KB
# None

# %%
#define data
x = [22, 24, 25, 25, 28, 29, 34, 37, 40, 44, 51, 48, 47, 50, 51]

# %%
from statsmodels.graphics import tsaplots
import matplotlib.pyplot as plt

#plot autocorrelation function
fig = tsaplots.plot_acf(x, lags=10)
plt.show()

# %%
from statsmodels.graphics import tsaplots
import matplotlib.pyplot as plt

#plot autocorrelation function
fig = tsaplots.plot_acf(x, lags=5)
plt.show()

# %%
from random import randrange
from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
series = [i+randrange(10) for i in range(1,100)]
result = seasonal_decompose(series, model='additive', period=1)
result.plot()
pyplot.show()

# %%
from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
series = [i**2.0 for i in range(1,100)]
result = seasonal_decompose(series, model='multiplicative', period=1)
result.plot()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('earthquakes.csv', header=0, index_col=0)
series.plot()
pyplot.show()

# %%
pip install scalecast
# Out:
# Collecting scalecast
#   Downloading SCALECAST-0.18.8.tar.gz (890 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.0/890.0 kB 16.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from scalecast) (1.2.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from scalecast) (0.13.5)
# Collecting tbats (from scalecast)
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from scalecast) (1.10.1)
# Collecting eli5 (from scalecast)
#   Downloading eli5-0.13.0.tar.gz (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.2/216.2 kB 26.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from scalecast) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from scalecast) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from scalecast) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from scalecast) (0.12.2)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from scalecast) (1.7.6)
# Requirement already satisfied: lightgbm>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from scalecast) (3.3.5)
# Collecting dask>=2023.3.2 (from scalecast)
#   Downloading dask-2023.7.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 52.2 MB/s eta 0:00:00
# Collecting catboost (from scalecast)
#   Downloading catboost-1.2-cp310-cp310-manylinux2014_x86_64.whl (98.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from scalecast) (3.0.10)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (8.1.3)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (23.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (6.0)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.3.2->scalecast) (0.12.0)
# Collecting importlib-metadata>=4.13.0 (from dask>=2023.3.2->scalecast)
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from lightgbm>=3.2.1->scalecast) (0.40.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->scalecast) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->scalecast) (3.1.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost->scalecast) (0.20.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost->scalecast) (5.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost->scalecast) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->scalecast) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->scalecast) (2022.7.1)
# Requirement already satisfied: attrs>17.1.0 in /usr/local/lib/python3.10/dist-packages (from eli5->scalecast) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from eli5->scalecast) (3.1.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from eli5->scalecast) (0.8.10)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scalecast) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scalecast) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scalecast) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scalecast) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scalecast) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->scalecast) (3.1.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->scalecast) (1.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels->scalecast) (0.5.3)
# Collecting pmdarima (from tbats->scalecast)
#   Downloading pmdarima-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 102.6 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2023.3.2->scalecast) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=3.0.0->eli5->scalecast) (2.1.3)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask>=2023.3.2->scalecast) (1.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost->scalecast) (8.2.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima->tbats->scalecast) (0.29.35)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima->tbats->scalecast) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima->tbats->scalecast) (67.7.2)
# Building wheels for collected packages: scalecast, eli5
#   Building wheel for scalecast (setup.py) ... done
#   Created wheel for scalecast: filename=SCALECAST-0.18.8-py3-none-any.whl size=111903 sha256=eff39545eebacba695db4f94635929283726b545a3f65e576c1bd5b2674f2c55
#   Stored in directory: /root/.cache/pip/wheels/ee/c3/95/9ced84cd0a8b34198d5cc67567389d1906b13408e627b31ca2
#   Building wheel for eli5 (setup.py) ... done
#   Created wheel for eli5: filename=eli5-0.13.0-py2.py3-none-any.whl size=107730 sha256=730725bd93c4fc905e64e697861bffec462374029c2f41b0dcdc1b2e9949552c
#   Stored in directory: /root/.cache/pip/wheels/b8/58/ef/2cf4c306898c2338d51540e0922c8e0d6028e07007085c0004
# Successfully built scalecast eli5
# Installing collected packages: importlib-metadata, dask, eli5, catboost, pmdarima, tbats, scalecast
#   Attempting uninstall: dask
#     Found existing installation: dask 2022.12.1
#     Uninstalling dask-2022.12.1:
#       Successfully uninstalled dask-2022.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# distributed 2022.12.1 requires dask==2022.12.1, but you have dask 2023.7.0 which is incompatible.
# Successfully installed catboost-1.2 dask-2023.7.0 eli5-0.13.0 importlib-metadata-6.8.0 pmdarima-2.0.3 scalecast-0.18.8 tbats-1.1.3

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.29.35)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.22.4)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (23.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
from scalecast.auxmodels import auto_arima

# %%
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm

df = pd.read_csv('earthquakes.csv', names=['value'], header=0)

model = pm.auto_arima(df.value, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0,
                      D=0,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True,
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=640.692, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=660.840, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=648.817, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=639.036, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=658.842, Time=0.01 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=640.580, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=640.728, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=637.076, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=638.727, Time=0.03 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=638.615, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=646.823, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=638.769, Time=0.06 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 0.538 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   99
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -316.538
# Date:                Mon, 10 Jul 2023   AIC                            637.076
# Time:                        11:32:17   BIC                            642.246
# Sample:                             0   HQIC                           639.167
#                                  - 99
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5596      0.081     -6.870      0.000      -0.719      -0.400
# sigma2        37.2715      4.961      7.512      0.000      27.547      46.996
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                 2.76
# Prob(Q):                              0.77   Prob(JB):                         0.25
# Heteroskedasticity (H):               0.64   Skew:                             0.38
# Prob(H) (two-sided):                  0.21   Kurtosis:                         3.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
